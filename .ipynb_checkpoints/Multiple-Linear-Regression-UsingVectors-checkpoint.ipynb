# %% [markdown]
# <h2 style='color:orange'><u><i><b>MULTIPLE LINEAR REGRESSION MODEL ( REPUTATION SCORE %AGE PREDICTION )</b></i></u></h2>
# <p>This model is tested on the following google scholors scrapped data of 500 top scholors of computer science present on the google scholors site.
# <br>In the below dataset there is one output reputation percentage or reputation score out of 500. By training model on these inputs and that one output either score %age or simple score i will predict the future repu score of the scholors.</p>

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("Data-Files/CS_Scholors_Reputation.csv")
dataset
# Out:
#           Author names  All Citations  Citations since 2020  All h-index  \
# 0           Jiawei Han         262906                 71320          210
# 1        Skander Gasmi         215766                202935           55
# 2         Philip S. Yu         215546                 98329          203
# 3     David S. Johnson         213524                 36872          116
# 4        Jure Leskovec         188462                125259          156
# ..                 ...            ...                   ...          ...
# 495         Xifeng Yan          30164                 10071           76
# 496  Charles A. Taylor          30164                 12789           81
# 497       Paul Debevec          30140                  9168           65
# 498    Haim J. Wolfson          30136                  6100           83
# 499       Joshy George          30109                 17809           68
#
#      h-index since 2020  All i10-index  i10-index since 2020  \
# 0                   113           1085                   674
# 1                    47             78                    64
# 2                   131           1593                   980
# 3                    60            391                   184
# 4                   130            380                   346
# ..                  ...            ...                   ...
# 495                  44            183                   126
# 496                  54            310                   256
# 497                  43            151                    96
# 498                  31            173                    75
# 499                  52            101                    97
#
#      Reputation Score since 2020  Reputation Percentage  \
# 0                         271.42                 54.284
# 1                         171.44                 34.288
# 2                         355.57                 71.114
# 3                         124.41                 24.882
# 4                         240.38                 48.076
# ..                           ...                    ...
# 495                        77.31                 15.462
# 496                       112.13                 22.426
# 497                        69.42                 13.884
# 498                        53.93                 10.786
# 499                        85.44                 17.088
#
#                                          Profile Links    Research Field
# 0    https://scholar.google.com/citations?hl=en&use...  Computer Science
# 1    https://scholar.google.com/citations?hl=en&use...  Computer Science
# 2    https://scholar.google.com/citations?hl=en&use...  Computer Science
# 3    https://scholar.google.com/citations?hl=en&use...  Computer Science
# 4    https://scholar.google.com/citations?hl=en&use...  Computer Science
# ..                                                 ...               ...
# 495  https://scholar.google.com/citations?hl=en&use...  Computer Science
# 496  https://scholar.google.com/citations?hl=en&use...  Computer Science
# 497  https://scholar.google.com/citations?hl=en&use...  Computer Science
# 498  https://scholar.google.com/citations?hl=en&use...  Computer Science
# 499  https://scholar.google.com/citations?hl=en&use...  Computer Science
#
# [500 rows x 11 columns]

# %% [markdown]
# <div style="background-color:#222; padding:10px; border-radius:10px;">
#     <p style='text-decoration:underline; font-weight:bold; font-style:italic;'>Picking 3 features from the data.</p>
#     <ul>
#     <li>Citations since 2020</li>
#     <li>h-index since 2020</li>
#     <li>i10-index since 2020</li>
#     <li><b>Output:</b> Reputaion Score %age out of 500</li>
#     </ul>
# </div>

# %%
citations = dataset["Citations since 2020"].tolist()
h_index = dataset["h-index since 2020"].tolist()
i10_index = dataset["i10-index since 2020"].tolist()
y_repu_score = dataset["Reputation Percentage"].tolist()
# Rounding reputations score %age
y_repu_score = [round(score,2) for score in y_repu_score]
model_data = pd.DataFrame({
 "Citations (x1)":citations,
  "H-index (x2)": h_index,
  "i10-index (x3)":i10_index,
  "Reputations Score %age (y)": y_repu_score  
})
model_data
# Out:
#      Citations (x1)  H-index (x2)  i10-index (x3)  Reputations Score %age (y)
# 0             71320           113             674                       54.28
# 1            202935            47              64                       34.29
# 2             98329           131             980                       71.11
# 3             36872            60             184                       24.88
# 4            125259           130             346                       48.08
# ..              ...           ...             ...                         ...
# 495           10071            44             126                       15.46
# 496           12789            54             256                       22.43
# 497            9168            43              96                       13.88
# 498            6100            31              75                       10.79
# 499           17809            52              97                       17.09
#
# [500 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(citations,y_repu_score,marker='x',c='g')
plt.xlabel("Total Citations since 2020 Part of Score (x1)")
plt.ylabel("Reputation Score Percentage")
plt.show()

# %%
plt.scatter(h_index,y_repu_score,marker='x',c='b')
plt.xlabel("Total H-index since 2020 Part of Score (x2)")
plt.ylabel("Reputation Score Percentage")
plt.show()

# %%
plt.scatter(i10_index,y_repu_score,marker='x',c='r')
plt.xlabel("Total Citations since 2020 Part of Score (x3)")
plt.ylabel("Reputation Score Percentage")
plt.show()

# %%
np.set_printoptions(suppress=True,precision=6)
x1 = np.array(citations)
x2 = np.array(h_index)
x3 = np.array(i10_index)

# %%
x_vector = np.column_stack((np.ones(500),x1,x2,x3))

# %%
print("Shape :",x_vector.shape)
print("Size :",x_vector.size)
x_vector
# Out:
# Shape : (500, 4)
# Size : 2000
# array([[     1.,  71320.,    113.,    674.],
#        [     1., 202935.,     47.,     64.],
#        [     1.,  98329.,    131.,    980.],
#        ...,
#        [     1.,   9168.,     43.,     96.],
#        [     1.,   6100.,     31.,     75.],
#        [     1.,  17809.,     52.,     97.]])

# %%
w = np.zeros(4)
w.reshape(4,1)
print("Weights Shape: ",w.shape)
print(w)
# Out:
# Weights Shape:  (4,)
# [0. 0. 0. 0.]

# %%
def hypothesis(x,w):
    return np.dot(x,w)

# %%
def loss(m,y,y_predicted):
    return((1/(2*m))*np.sum(np.square(y_predicted-y)))

# %%
def gradient(m,x,y,y_predicted):
    return((1/m)*np.dot(x.T,y_predicted-y))

# %%
l=[]
epochs=[]
for epoch in range(10):
    epochs.append(epoch)
    y_pred=hypothesis(x_vector,w)
    los=loss(500,y_repu_score,y_pred)
    l.append(los)
    dw=gradient(500,x_vector,y_repu_score,y_pred)
    dw = 0.001 * dw
    w = w - dw

# %%
l
# Out:
# [269.2607264,
#  170746418503936.3,
#  1.4540365287942087e+26,
#  1.2382234696837831e+38,
#  1.0544421206165861e+50,
#  8.979382259765666e+61,
#  7.646631729757352e+73,
#  6.51169257739763e+85,
#  5.545204963582169e+97,
#  4.722166736628285e+109]
